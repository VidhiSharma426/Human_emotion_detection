# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (4.9.0.80)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from opencv-python) (1.26.4)

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.12.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.64.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.3)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.43.0)
# Requirement already satisfied: rich in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sanjay kumar\appdata\roaming\python\python312\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sanjay kumar\anaconda3\envs\emotion_detection_course\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Emotion Dectector

# %% [markdown]
# ### Importing required libraries

# %%
import matplotlib.pyplot as plt # for data visualisation
from glob import glob # for making list of directories
import cv2 
import random 
import os 
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,Flatten,Conv2D
from tensorflow.keras.layers import BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG,Image
import tensorflow as tf
print("Tensorflow version: ",tf.__version__)
# Out:
# Tensorflow version:  2.16.1

# %% [markdown]
# ### Exploring Dataset

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image))
    plt.axis('off')

# %% [markdown]
# ### Preparing Data for training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
target_size = (img_size,img_size),
color_mode = "grayscale",
batch_size=batch_size,
class_mode ="categorical",
shuffle=True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
target_size = (img_size,img_size),
color_mode = "grayscale",
batch_size=batch_size,
class_mode ="categorical",
shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# ### Defining Model

# %%
def convolution(input_tensor,filters,kernel_size):
    x = Conv2D(filters = filters,kernel_size = kernel_size,padding="same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2,2))(x)
    x = Dropout(0.25)(x)

    return x

# %%
def Dense_f(input_tensor,nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)

    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = convolution(inputs,32,(3,3))
    conv_2 = convolution(conv_1,64,(5,5))
    conv_3 = convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)

    dense_1 = Dense_f(flatten,256)
    
    output = Dense(7,activation="softmax")(dense_1)
    model = Model(inputs =[inputs],outputs=[output])

    model.compile(loss =['categorical_crossentropy'],optimizer ='adam',metrics=['accuracy'])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 48, 48, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 48, 48, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,309,063 (4.99 MB)
#  Trainable params: 1,308,103 (4.99 MB)
#  Non-trainable params: 960 (3.75 KB)

# %% [markdown]
# ### Initializing the model

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps =validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.weights.h5",monitor='val_accuracy',save_weights_only=True,mode="max",verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# ### Training the Model

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data = validation_generator,
    validation_steps=validation_steps,
    callbacks = callbacks
)
# Out:
# Epoch 1/15
# c:\Users\SANJAY KUMAR\anaconda3\envs\Emotion_detection_course\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3027 - loss: 1.8679
# Epoch 1: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 568s 1s/step - accuracy: 0.3029 - loss: 1.8675 - val_accuracy: 0.3758 - val_loss: 1.6553
# Epoch 2/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:58 266ms/step - accuracy: 0.4375 - loss: 1.3841
# Epoch 2: saving model to model_weights.weights.h5
# c:\Users\SANJAY KUMAR\anaconda3\envs\Emotion_detection_course\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 1s 548us/step - accuracy: 0.4375 - loss: 1.3841 - val_accuracy: 0.5000 - val_loss: 1.1330
# Epoch 3/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - accuracy: 0.4523 - loss: 1.4216
# Epoch 3: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 496s 1s/step - accuracy: 0.4524 - loss: 1.4216 - val_accuracy: 0.4639 - val_loss: 1.3986
# Epoch 4/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:57 263ms/step - accuracy: 0.5625 - loss: 1.2914
# Epoch 4: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - accuracy: 0.5625 - loss: 1.2914 - val_accuracy: 0.6000 - val_loss: 1.0922
# Epoch 5/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 706ms/step - accuracy: 0.5107 - loss: 1.2908
# Epoch 5: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 416s 929ms/step - accuracy: 0.5107 - loss: 1.2908 - val_accuracy: 0.4856 - val_loss: 1.3369
# Epoch 6/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:50 248ms/step - accuracy: 0.5938 - loss: 1.1323
# Epoch 6: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.5938 - loss: 1.1323 - val_accuracy: 0.6000 - val_loss: 1.1834
# Epoch 7/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.5406 - loss: 1.2110
# Epoch 7: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 332s 740ms/step - accuracy: 0.5406 - loss: 1.2110 - val_accuracy: 0.4615 - val_loss: 1.3584
# Epoch 8/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:51 250ms/step - accuracy: 0.4844 - loss: 1.4109
# Epoch 8: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.4844 - loss: 1.4109 - val_accuracy: 0.6000 - val_loss: 1.1397
# Epoch 9/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.5603 - loss: 1.1656
# Epoch 9: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 126s 280ms/step - accuracy: 0.5603 - loss: 1.1656 - val_accuracy: 0.5499 - val_loss: 1.1819
# Epoch 10/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:48 244ms/step - accuracy: 0.5781 - loss: 1.0246
# Epoch 10: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.5781 - loss: 1.0246 - val_accuracy: 0.3000 - val_loss: 1.1341
# Epoch 11/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.5927 - loss: 1.0870
# Epoch 11: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 123s 273ms/step - accuracy: 0.5927 - loss: 1.0871 - val_accuracy: 0.5456 - val_loss: 1.1905
# Epoch 12/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:53 254ms/step - accuracy: 0.6094 - loss: 1.0902
# Epoch 12: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - accuracy: 0.6094 - loss: 1.0902 - val_accuracy: 0.6000 - val_loss: 0.9015
# Epoch 13/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6049 - loss: 1.0568
# Epoch 13: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 117s 261ms/step - accuracy: 0.6049 - loss: 1.0568 - val_accuracy: 0.5622 - val_loss: 1.1612
# Epoch 14/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 1:45 236ms/step - accuracy: 0.6250 - loss: 1.0285
# Epoch 14: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step - accuracy: 0.6250 - loss: 1.0285 - val_accuracy: 0.5000 - val_loss: 1.2690
# Epoch 15/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6242 - loss: 1.0124
# Epoch 15: saving model to model_weights.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 120s 268ms/step - accuracy: 0.6241 - loss: 1.0124 - val_accuracy: 0.5650 - val_loss: 1.1723

# %% [markdown]
# ### Model Evaluation

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - accuracy: 0.5623 - loss: 1.1733
# [1.1722534894943237, 0.5650599002838135]

# %% [markdown]
# ### Plotting Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model_loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top = 1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model_loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top = 1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# ### Saving Model

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
